# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
data_to_load = Path("WHO_Data/WHOMortalityDatabase_Map_a. Malignant skin melanoma_19th December 2023 23 17.csv")

data = pd.read_csv(data_to_load, skiprows=6)


#Combine the data into a single dataset.  
#school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
#school_summary.set_index('Student ID', inplace=True)

data
# Out:
#    Region Code Region Name  Country Code  Country Name    Year          Sex  \
# EU      Europe         ALB       Albania          1987     All      Age_all
# EU      Europe         ALB       Albania          1987     All        Age00
# EU      Europe         ALB       Albania          1987     All     Age01_04
# EU      Europe         ALB       Albania          1987     All     Age05_09
# EU      Europe         ALB       Albania          1987     All     Age10_14
# ..         ...         ...           ...           ...     ...          ...
# AF      Africa         ZAF  South Africa          2015  Female     Age70_74
# AF      Africa         ZAF  South Africa          2015  Female     Age75_79
# AF      Africa         ZAF  South Africa          2015  Female     Age80_84
# AF      Africa         ZAF  South Africa          2015  Female   Age85_over
# AF      Africa         ZAF  South Africa          2015  Female  Age_unknown
#
#    Age group code  Age Group    Number  \
# EU          [All]       22.0  0.126977
# EU            [0]        0.0  0.000000
# EU          [1-4]        0.0  0.000000
# EU          [5-9]        0.0  0.000000
# EU        [10-14]        0.0  0.000000
# ..            ...        ...       ...
# AF        [70-74]       16.0  0.102512
# AF        [75-79]       13.0  0.074269
# AF        [80-84]       16.0  0.100288
# AF          [85+]       20.0  0.078052
# AF      [Unknown]        0.0  0.000000
#
#     Percentage of cause-specific deaths out of total deaths  \
# EU                                           1.036609
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# EU                                                NaN
# ..                                                ...
# AF                                                NaN
# AF                                                NaN
# AF                                                NaN
# AF                                                NaN
# AF                                                NaN
#
#     Age-standardized death rate per 100 000 standard population  \
# EU                                           0.715191
# EU                                           0.000000
# EU                                           0.000000
# EU                                           0.000000
# EU                                           0.000000
# ..                                                ...
# AF                                           3.340592
# AF                                           4.044804
# AF                                           9.174312
# AF                                          27.331365
# AF                                                NaN
#
#     Death rate per 100 000 population
# EU                                NaN
# EU                                NaN
# EU                                NaN
# EU                                NaN
# EU                                NaN
# ..                                ...
# AF                                NaN
# AF                                NaN
# AF                                NaN
# AF                                NaN
# AF                                NaN
#
# [183036 rows x 12 columns]
